# %%
import pandas as pd
import csv

# %%
df1 = pd.read_csv('/Users/renetanjuakio/Documents/GitHub/Capstone-Project-1/ZipcodeIncome.csv',)
df1.describe()
df1
# Out:
#          Zip  Median    Mean     Pop
# 0       1001  56,663  66,688  16,445
# 1       1002  49,853  75,063  28,069
# 2       1003  28,462  35,121   8,491
# 3       1005  75,423  82,442   4,798
# 4       1007  79,076  85,802  12,962
# 5       1008  63,980  78,391   1,244
# 6       1009  51,452  66,737     889
# 7       1010  75,625  80,919   3,340
# 8       1011  63,476  77,443   1,323
# 9       1012  58,750  74,722     677
# 10      1013  36,578  46,179  22,907
# 11      1020  50,058  58,516  29,626
# 12      1022  50,440  60,797   2,124
# 13      1026  60,320  71,505   1,052
# 14      1027  58,573  66,613  17,452
# 15      1028  80,252  94,891  14,143
# 16      1029  62,955  97,075     663
# 17      1030  71,106  81,727  11,702
# 18      1031  61,250  76,417   1,192
# 19      1032  67,692  79,796     498
# 20      1034  63,980  78,391   1,910
# 21      1035  69,911  73,973   4,801
# 22      1036  78,869  95,493   5,089
# 23      1037  61,250  76,417     627
# ...

# %%
#inspecting data set
print(df1.head())
# Out:
#     Zip  Median    Mean     Pop
# 0  1001  56,663  66,688  16,445
# 1  1002  49,853  75,063  28,069
# 2  1003  28,462  35,121   8,491
# 3  1005  75,423  82,442   4,798
# 4  1007  79,076  85,802  12,962

# %%
df1.dtypes
# Out:
# Zip        int64
# Median    object
# Mean      object
# Pop       object
# dtype: object

# %%
#assign Mean
Mean = df1.iloc[:,[2]]

# %%
#assign Median
Median = df1.iloc[:,[1]]
Zip = df1.iloc[:,[0]]
Pop = df1.iloc[:,[3]]

# %%
#convert all to string
strMean = str(Mean)
strMedian = str(Median)
strZip = str(df1['Zip'])
strPop = str(Pop)

# %%
#take out commas
sMean = strMean.replace(',', '')
sMedian = strMedian.replace(',', '')
sPop = strPop.replace(',', '')

# %%
String str = "1234567890";
int fullInt = Integer.parseInt(str);
String first4char = str.substring(0,4);
int intForFirst4Char = Integer.parseInt(first4char);
